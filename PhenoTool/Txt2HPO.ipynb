# %%
from txt2hpo.extract import Extractor
extract = Extractor()
#txt = "patient with developmental delay and hypotonia"
#txt = 


result = extract.hpo(txt.lower())

#print(result.hpids)

# %%
import pandas as pd
df_anno = pd.read_csv('data/df_train_bulk.txt', sep='|')

# %%
df_anno.head()
# Out:
#    MRN                                               NOTE
# 0    1  Townes-Brocks syndrome (TBS) is an autosomal d...
# 1    3  Angelman syndrome (AS) is a neurodevelopmental...
# 2    4  Prader-Willi syndrome (PWS) and Angelman syndr...
# 3    6  The clinical features of Angelman syndrome (AS...
# 4    7  'Neurofibromatosis type 2 (NF2) is a highly pe...

# %% [markdown]
# ## import Gold Standard

# %%
import pandas as pd
import sys
sys.path.append('../')

df_train = pd.read_csv('../data/Bio-Lark/df_train.csv')
df_test = pd.read_csv('../data/Bio-Lark/df_test.csv')
df_valid = pd.read_csv('../data/Bio-Lark/df_valid.csv')

df_train.head()
# Out:
#    entID  docID  start  end         hpo                  entity  \
# 0     12      1     35   53  HP_0000006      autosomal dominant
# 1     13      1     95  114  HP_0003828     variable expression
# 2     14      1    139  161  HP_0000356  external ear anomalies
# 3     15      1    163  175  HP_0000365            hearing loss
# 4     16      1    177  197  HP_0001841    preaxial polydactyly
#
#                                                 text
# 0  Townes-Brocks syndrome (TBS) is an autosomal d...
# 1  Townes-Brocks syndrome (TBS) is an autosomal d...
# 2  Townes-Brocks syndrome (TBS) is an autosomal d...
# 3  Townes-Brocks syndrome (TBS) is an autosomal d...
# 4  Townes-Brocks syndrome (TBS) is an autosomal d...

# %% [markdown]
# ## Employ txt2hpo to txt

# %%
from txt2hpo.extract import Extractor
extract = Extractor()

df_anno['HPO'] = df_anno['NOTE'].apply(lambda x: extract.hpo(x.lower()).hpids)
# Out:
# 2020-08-25 16:17:23,569 - txt2hpo - INFO - txt2hpo 0.2.2
# 2020-08-25 16:17:23,655 - txt2hpo - INFO - Using configuration file: \Users\levrex\.txt2hpo\txt2hpo.ini
# 2020-08-25 16:17:23,931 - phenopy - INFO - checking if config file exists: \Users\levrex\.phenopy
# 2020-08-25 16:17:23,943 - phenopy - INFO - phenopy 0.4.2
# 2020-08-25 16:17:23,970 - phenopy - INFO - Using configuration file: \Users\levrex\.phenopy\phenopy.ini
# 2020-08-25 16:17:47,273 - txt2hpo - INFO - Using scispaCy language model

# %% [markdown]
# ### save annotations of txt2hpo

# %%
df_anno.to_csv('results/annotations_txt2hpo.csv', sep='|')

# %% [markdown]
# ## Evaluate performance of txt2hpo

# %%
import networkx
import obonet

url = '../phenopy_mod/.phenopy/data/hp.obo'
graph = obonet.read_obo(url)

# %%
import DeepPhenotyping_functions as func
d_trans= func.generate_hpo_updgrade_list(graph)

# %%
df_anno
# Out:
#     MRN                                               NOTE
# 0     1  Townes-Brocks syndrome (TBS) is an autosomal d...
# 1     3  Angelman syndrome (AS) is a neurodevelopmental...
# 2     4  Prader-Willi syndrome (PWS) and Angelman syndr...
# 3     6  The clinical features of Angelman syndrome (AS...
# 4     7  'Neurofibromatosis type 2 (NF2) is a highly pe...
# ..  ...                                                ...
# 71  209  'Undiagnosed institutionalised patients were r...
# 72  210  Neurofibromatosis 1 and neurofibromatosis 2 ar...
# 73  218  The causal heterogeneity of Angelman syndrome ...
# 74  219  'Six cases of this syndrome previously reporte...
# 75  225  Mutations of the human Patched gene ( PTCH ) h...
#
# [76 rows x 2 columns]

# %%
import numpy as np
import DeepPhenotyping_functions as func

y_test = []
y_pred = []

# set1 - set2 & set2 - set1
TP = 0 
TN = 0
FP = 0
FN = 0

for doc_id in list(df_train['docID'].unique()):
    inferred = df_anno[df_anno['MRN']==doc_id]['HPO'].iloc[0]
    gold = df_train[df_train['docID']==doc_id]['hpo'].unique()
    gold = [i.replace('_', ':') for i in gold]
    gold = func.update_deprecated_OBO(list(gold), d_trans)
    #gold = in_hpo(list(gold), list(id_to_name.keys()))
    #break
    #print(gold, '\n', inferred)
    TP += len(np.intersect1d(list(set(gold)), list(set(inferred))))
    FN += len(set(gold) - set(inferred))
    FP +=  len(set(inferred) - set(gold))
    
    for i in range(len(np.intersect1d(list(set(gold)), list(set(inferred))))):
        y_test.append(1)
        y_pred.append(1)
    for i in range(len(set(gold) - set(inferred))):
        y_test.append(1)
        y_pred.append(0)
    for i in range(len(set(inferred) - set(gold))):
        y_test.append(0)
        y_pred.append(1)
    #print('TP: ', len(np.intersect1d(list(set(gold)), list(set(inferred)))))
    print('FN: ', len(set(gold) - set(inferred)))
    print('FP: ', len(set(inferred) - set(gold)))
    print(doc_id, len(inferred), len(gold))
    y_pred.append(0)
    y_test.append(0)
    
cnf_matrix = np.array([[TP, FN], [FP, TN]])

plt = func.print_confusion_matrix(cnf_matrix, classes=['HPO', 'No-HPO'], title='Confusion matrix')
# Out:
# FN:  5
# FP:  2
# 1 7 10
# FN:  2
# FP:  0
# 3 0 2
# FN:  2
# FP:  0
# 4 0 2
# FN:  3
# FP:  1
# 6 8 10
# FN:  3
# FP:  3
# 7 7 8
# FN:  11
# FP:  1
# 11 5 15
# FN:  2
# FP:  1
# 12 5 7
# FN:  1
# FP:  0
# 13 2 3
# FN:  2
# FP:  0
# 21 2 4
# FN:  2
# FP:  0
# 28 1 3
# FN:  0
# FP:  0
# 31 3 3
# FN:  5
# FP:  2
# 32 5 8
# FN:  2
# FP:  0
# 34 1 3
# FN:  5
# FP:  2
# 39 9 12
# FN:  2
# FP:  0
# 41 2 4
# FN:  7
# FP:  3
# 42 7 11
# FN:  5
# FP:  1
# 44 3 7
# FN:  1
# FP:  0
# 52 1 2
# FN:  4
# FP:  2
# 53 9 11
# FN:  2
# FP:  2
# 57 4 4
# FN:  3
# FP:  3
# 58 6 6
# FN:  7
# FP:  0
# 61 4 11
# FN:  0
# FP:  0
# 64 1 1
# FN:  0
# FP:  0
# 71 1 1
# FN:  1
# FP:  0
# 72 0 1
# FN:  5
# FP:  1
# 76 4 8
# FN:  4
# FP:  1
# 78 4 7
# FN:  1
# FP:  0
# 80 1 2
# FN:  1
# FP:  0
# 81 0 1
# FN:  4
# FP:  1
# 83 5 8
# FN:  7
# FP:  3
# 87 11 15
# FN:  3
# FP:  1
# 88 2 4
# FN:  3
# FP:  1
# 91 3 5
# FN:  8
# FP:  1
# 92 9 17
# FN:  1
# FP:  0
# 94 2 3
# FN:  3
# FP:  1
# 98 6 9
# FN:  2
# FP:  0
# 102 0 2
# FN:  6
# FP:  0
# 105 0 6
# FN:  2
# FP:  2
# 110 5 5
# FN:  0
# FP:  0
# 115 1 1
# FN:  2
# FP:  2
# 116 5 5
# FN:  2
# FP:  1
# 121 3 4
# FN:  1
# FP:  1
# 122 1 1
# FN:  4
# FP:  1
# 128 7 10
# FN:  5
# FP:  0
# 130 3 8
# FN:  1
# FP:  1
# 131 3 3
# FN:  4
# FP:  0
# 134 5 9
# FN:  6
# FP:  3
# 136 7 11
# FN:  3
# FP:  1
# 141 4 7
# FN:  5
# FP:  0
# 145 3 8
# FN:  0
# FP:  0
# 151 1 1
# FN:  4
# FP:  2
# 152 5 7
# FN:  7
# FP:  1
# 160 5 11
# FN:  6
# FP:  0
# 166 1 7
# FN:  1
# FP:  1
# 171 2 2
# FN:  4
# FP:  1
# 172 5 8
# FN:  2
# FP:  1
# 175 1 2
# FN:  0
# FP:  3
# 176 4 1
# FN:  3
# FP:  0
# 179 2 5
# FN:  4
# FP:  2
# 181 5 8
# FN:  2
# FP:  0
# 183 1 3
# FN:  6
# FP:  0
# 187 1 7
# FN:  6
# FP:  1
# 188 7 14
# FN:  2
# FP:  1
# 189 2 3
# FN:  1
# FP:  1
# 190 2 2
# FN:  6
# FP:  2
# 191 8 12
# FN:  2
# FP:  1
# 194 3 4
# FN:  4
# FP:  0
# 198 8 12
# FN:  1
# FP:  0
# 204 3 4
# FN:  1
# FP:  0
# 205 2 3
# FN:  4
# FP:  2
# 208 4 6
# FN:  11
# FP:  3
# 209 11 19
# FN:  1
# FP:  2
# 210 3 2
# FN:  1
# FP:  0
# 218 0 1
# FN:  5
# FP:  2
# 219 5 9
# FN:  0
# FP:  1
# 225 4 3
# Confusion matrix, without normalization
# [[210 244]
#  [ 72   0]]

# %%
import importlib as imp

imp.reload(func)

func.plot_performance(y_pred,y_test, clf_name='txt2hpo')

# %%
func.print_perf(TP, FP, TN, FN)
# Out:
# Sensitivity:	 0.46
# Specificity:	 0.0
# PPV:		 0.74
# NPV:		 0.0
# F1:		 0.57
# Accuracy:	 0.4
